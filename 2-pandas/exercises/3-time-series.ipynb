# %% [markdown]
# # Optional exercise
#
# This exercise is a bit different. We are going to explore time series data.
# Whenever time is involved, it complicates the analysis a bit more (or a lot more, depends on the data and the requirements.)
#
# This one involves knowledge that I have not covered during the live demo. The challenge here is to figure out for yourselves how to use the pandas library.
#
# Be sure to check out the `example` folder for this exercise. It includes a sample time series analysis.
#
# Also, feel free to browse the pandas [documentation](https://pandas.pydata.org/docs/index.html) or ask questions on Google, example: `How to set index to datetime column in pandas`

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %% [markdown]
# ### Step 2. Examine data from file `invest.csv`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 3. Assign it to a variable called `df`

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %% [markdown]
# ### Step 6. What is the type of the index?

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %% [markdown]
# ### BONUS: Create your own question and answer it.
